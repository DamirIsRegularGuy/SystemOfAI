# %%
import pandas as pd
import numpy as np

df = pd.read_csv("foor.csv")

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages Total day minutes  Total day calls  \
# ...

# %%
df.sort_values(by = "Total day charge", ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1351    LA              13        415                 No              No
# 181     AK             126        415                 No              No
# 2973    NE              95        510                 No              No
# 2859    WV              87        415                 No              No
# 603     MI              53        415                 No              No
#
#       Number vmail messages Total day minutes  Total day calls  \
# 1351                      0              58,4              121
# 181                       0              58,2               94
# 2973                      0              58,2               96
# 2859                      0              58,0              125
# 603                       0              57,5               95
#
#      Total day charge Total eve minutes  Total eve calls Total eve charge  \
# ...

# %%
df.sort_values(by=['Churn', 'Total day charge'], ascending=[True, False])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1351    LA              13        415                 No              No
# 2973    NE              95        510                 No              No
# 2859    WV              87        415                 No              No
# 603     MI              53        415                 No              No
# 735     DC             169        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 258     KS              92        408                Yes              No
# 21      CO              77        408                 No              No
# 77      NY             144        408                 No              No
# 1538    WV             113        415                 No              No
# 1345    SD              98        415                 No              No
#
#       Number vmail messages Total day minutes  Total day calls  \
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492
